# %% [markdown]
# <a href="https://colab.research.google.com/github/sam02/tp547/blob/main/codigos/codigos_aula9/sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scipy
# !pip install numpy
# !pip install matplotlib

# %%
import scipy
from scipy.fftpack import fft
import numpy as np
from scipy import pi
import matplotlib.pyplot as plt
t = np.linspace(0,120,4000)


signal = 10*np.sin(2*pi*2.0*t) + 5*np.sin(2*pi*8.0*t) + 2*np.random.random(len(t))

FFT = abs(scipy.fftpack.fft(signal))
freqs = scipy.fftpack.fftfreq(signal.size, t[1]-t[0])

plt.subplot(211)
plt.plot(t, signal)
plt.subplot(212)
plt.plot(freqs,20*np.log10(FFT),'x')
plt.show()
