# %% [markdown]
# <a href="https://colab.research.google.com/github/sam02/tp547/blob/main/codigos/codigos_aula8/raio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

N=10000
R=10
X=np.array([])
Y=np.array([])
for i in range(1,N):
    angulo = np.random.uniform(0,1)*2*np.pi
    raio= R*np.sqrt(np.random.uniform(0,1))
    x = raio * np.cos(angulo)
    y = raio * np.sin(angulo)
    X = np.append(X, x)
    Y = np.append(Y, y)

plt.plot(X,Y,'o')
plt.show()
